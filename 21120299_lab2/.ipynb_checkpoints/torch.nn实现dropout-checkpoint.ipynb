# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.utils import data
from IPython import display

# %%
input_size = 784  # 输入层神经元个数,因为像素大小为28*28，总共784个
hidden_size = 256  # 隐藏层神经元个数
batch_size = 128  # 批处理大小，采用小批量梯度下降算法
num_classes =10

# %%
# MNIST dataset
train_dataset = torchvision.datasets.MNIST(root="./", train=True, transform= transforms.ToTensor(),download=True)
test_dataset = torchvision.datasets.MNIST(root="./", train=False, transform= transforms.ToTensor(),download=True)
# Data loader 实现数据加载功能
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)  # shuffle= true表示每次迭代都随机加载训练集
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size,shuffle=False)

# %%
# drop_prob = 0.2
# drop_prob = 0.4
drop_prob = 0.6

# %%
class FlattenLayer(nn.Module):
    def __init__(self):
        super(FlattenLayer, self).__init__()
    def forward(self, x):
        return x.view(x.shape[0],-1)
net = nn.Sequential(
    FlattenLayer(),
    nn.Linear(input_size, hidden_size),
    nn.ReLU(),
    nn.Dropout(drop_prob),
    nn.Linear(hidden_size, num_classes)
    )

# %%
for param in net.parameters():
    nn.init.normal_(param, mean=0, std=0.01)

# %%
loss = nn.CrossEntropyLoss()

# %%
lr = 0.1
optimizer = optim.SGD(net.parameters(), lr=lr)

# %%
def evaluate_accuracy(data_inter,net,loss):
    acc_num,n = 0.0,0
    test_l_sum = 0.0
    for X,y in data_inter:
        acc_num+=(net(X).argmax(dim=1) == y).float().sum().item()
        l = loss(net(X),y).sum()
        test_l_sum+=l.item()
        n += y.shape[0]
    return acc_num/n,test_l_sum/n

# %%
x_l = []
train_loss = []
test_loss = []

# %%
def train(net, train_iter, test_iter, loss, num_epochs, batch_size, params=None, lr=None, optimizer=None):
    for epoch in range(num_epochs):
        train_l_sum, train_acc_sum, n = 0.0, 0.0, 0
        for X, y in train_iter:
            y_hat = net(X)
            l = loss(y_hat, y).sum()
            if optimizer is not None:
                optimizer.zero_grad()
            elif params is not None and params[0].grad is not None:
                for param in params:
                    param.grad.data.zero_()
            l.backward()
            if optimizer is None:
                optimizer = torch.optim.SGD(net.parameters(), lr=0.1)  # 学习率自适应的优化算法
            else:
                optimizer.step()
            train_l_sum += l.item()
            train_acc_sum += (y_hat.argmax(dim=1) == y).sum().item()
            n += y.shape[0]
        test_acc,test_l = evaluate_accuracy(test_iter, net,loss)
        x_l.append(epoch + 1)
        train_loss.append(train_l_sum / n)
        test_loss.append(test_l)
        print('epoch %d, train_loss %.4f, train acc %.3f, test_loss %.4f, test acc %.3f'
              % (epoch + 1, train_l_sum / n, train_acc_sum / n, test_l, test_acc))

# %%
def Draw_Loss_Curve(title):
    plt.figure(figsize=(15, 9))
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.title("Loss Function")
    plt.plot(x_l, train_loss, label=u'Train Loss')
    plt.legend()
    p2 = plt.plot(x_l, test_loss, label=u'Test Loss')
    plt.legend()
    plt.title(title)
    plt.show()

# %%
num_epochs = 30
train(net, train_loader, test_loader, loss, num_epochs, batch_size, net.parameters(), lr, optimizer)
# Out:
# epoch 1, train_loss 0.0058, train acc 0.811, test_loss 0.0028, test acc 0.900
# epoch 2, train_loss 0.0025, train acc 0.907, test_loss 0.0022, test acc 0.921
# epoch 3, train_loss 0.0020, train acc 0.926, test_loss 0.0018, test acc 0.934
# epoch 4, train_loss 0.0017, train acc 0.937, test_loss 0.0015, test acc 0.944
# epoch 5, train_loss 0.0015, train acc 0.947, test_loss 0.0013, test acc 0.950
# epoch 6, train_loss 0.0013, train acc 0.953, test_loss 0.0012, test acc 0.955
# epoch 7, train_loss 0.0012, train acc 0.957, test_loss 0.0011, test acc 0.960
# epoch 8, train_loss 0.0010, train acc 0.962, test_loss 0.0010, test acc 0.961
# epoch 9, train_loss 0.0010, train acc 0.965, test_loss 0.0009, test acc 0.965
# epoch 10, train_loss 0.0009, train acc 0.968, test_loss 0.0009, test acc 0.965
# epoch 11, train_loss 0.0008, train acc 0.970, test_loss 0.0009, test acc 0.967
# epoch 12, train_loss 0.0008, train acc 0.972, test_loss 0.0008, test acc 0.967
# epoch 13, train_loss 0.0007, train acc 0.973, test_loss 0.0008, test acc 0.970
# epoch 14, train_loss 0.0007, train acc 0.974, test_loss 0.0008, test acc 0.971
# epoch 15, train_loss 0.0007, train acc 0.976, test_loss 0.0007, test acc 0.971
# epoch 16, train_loss 0.0006, train acc 0.977, test_loss 0.0007, test acc 0.971
# epoch 17, train_loss 0.0006, train acc 0.978, test_loss 0.0007, test acc 0.972
# epoch 18, train_loss 0.0006, train acc 0.979, test_loss 0.0007, test acc 0.975
# epoch 19, train_loss 0.0006, train acc 0.980, test_loss 0.0007, test acc 0.974
# epoch 20, train_loss 0.0005, train acc 0.981, test_loss 0.0007, test acc 0.974
# epoch 21, train_loss 0.0005, train acc 0.981, test_loss 0.0006, test acc 0.974
# epoch 22, train_loss 0.0005, train acc 0.982, test_loss 0.0006, test acc 0.973
# epoch 23, train_loss 0.0005, train acc 0.983, test_loss 0.0007, test acc 0.974
# epoch 24, train_loss 0.0004, train acc 0.984, test_loss 0.0006, test acc 0.975
# epoch 25, train_loss 0.0004, train acc 0.984, test_loss 0.0006, test acc 0.976
# epoch 26, train_loss 0.0004, train acc 0.984, test_loss 0.0006, test acc 0.975
# epoch 27, train_loss 0.0004, train acc 0.984, test_loss 0.0006, test acc 0.976
# epoch 28, train_loss 0.0004, train acc 0.986, test_loss 0.0006, test acc 0.976
# epoch 29, train_loss 0.0004, train acc 0.987, test_loss 0.0006, test acc 0.977
# epoch 30, train_loss 0.0004, train acc 0.986, test_loss 0.0006, test acc 0.976

# %%
Draw_Loss_Curve('drop_prob=0.2')

# %%
# %%
train(net, train_loader, test_loader, loss, num_epochs, batch_size, net.parameters(), lr, optimizer)
# Out:
# epoch 1, train_loss 0.0064, train acc 0.772, test_loss 0.0032, test acc 0.887
# epoch 2, train_loss 0.0029, train acc 0.896, test_loss 0.0024, test acc 0.907
# epoch 3, train_loss 0.0023, train acc 0.916, test_loss 0.0021, test acc 0.924
# epoch 4, train_loss 0.0020, train acc 0.927, test_loss 0.0019, test acc 0.932
# epoch 5, train_loss 0.0018, train acc 0.935, test_loss 0.0016, test acc 0.938
# epoch 6, train_loss 0.0016, train acc 0.940, test_loss 0.0016, test acc 0.941
# epoch 7, train_loss 0.0015, train acc 0.945, test_loss 0.0015, test acc 0.947
# epoch 8, train_loss 0.0014, train acc 0.948, test_loss 0.0014, test acc 0.948
# epoch 9, train_loss 0.0013, train acc 0.951, test_loss 0.0013, test acc 0.949
# epoch 10, train_loss 0.0013, train acc 0.954, test_loss 0.0013, test acc 0.953
# epoch 11, train_loss 0.0012, train acc 0.956, test_loss 0.0012, test acc 0.953
# epoch 12, train_loss 0.0011, train acc 0.959, test_loss 0.0012, test acc 0.954
# epoch 13, train_loss 0.0011, train acc 0.959, test_loss 0.0012, test acc 0.954
# epoch 14, train_loss 0.0011, train acc 0.961, test_loss 0.0011, test acc 0.958
# epoch 15, train_loss 0.0010, train acc 0.961, test_loss 0.0011, test acc 0.960
# epoch 16, train_loss 0.0010, train acc 0.963, test_loss 0.0011, test acc 0.959
# epoch 17, train_loss 0.0010, train acc 0.964, test_loss 0.0011, test acc 0.961
# epoch 18, train_loss 0.0009, train acc 0.965, test_loss 0.0010, test acc 0.961
# epoch 19, train_loss 0.0009, train acc 0.966, test_loss 0.0010, test acc 0.960
# epoch 20, train_loss 0.0009, train acc 0.967, test_loss 0.0010, test acc 0.964
# epoch 21, train_loss 0.0009, train acc 0.967, test_loss 0.0010, test acc 0.963
# epoch 22, train_loss 0.0009, train acc 0.968, test_loss 0.0010, test acc 0.962
# epoch 23, train_loss 0.0008, train acc 0.969, test_loss 0.0010, test acc 0.964
# epoch 24, train_loss 0.0008, train acc 0.970, test_loss 0.0010, test acc 0.963
# epoch 25, train_loss 0.0008, train acc 0.970, test_loss 0.0010, test acc 0.962
# epoch 26, train_loss 0.0008, train acc 0.970, test_loss 0.0009, test acc 0.963
# epoch 27, train_loss 0.0008, train acc 0.971, test_loss 0.0009, test acc 0.965
# epoch 28, train_loss 0.0007, train acc 0.972, test_loss 0.0010, test acc 0.964
# epoch 29, train_loss 0.0007, train acc 0.972, test_loss 0.0009, test acc 0.965
# epoch 30, train_loss 0.0007, train acc 0.972, test_loss 0.0009, test acc 0.965

# %%
Draw_Loss_Curve('drop_prob=0.6')
